# %%
import torch,torchtext
from torchtext.legacy import data

SEED = 1234

torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

TEXT = data.Field(tokenize = 'spacy',
                  tokenizer_language = 'en_core_web_sm',
                  include_lengths = True)
LABEL = data.LabelField(dtype = torch.float)

# %%
from torchtext.legacy import datasets

train_data, test_data = datasets.IMDB.splits(TEXT, LABEL)

# %%
print(f'Number of training examples: {len(train_data)}')
print(f'Number of testing examples: {len(test_data)}')
# Out:
# Number of training examples: 25000
# Number of testing examples: 25000

# %%
import random

train_data, valid_data = train_data.split(random_state = random.seed(SEED))

# %%
print(f'Number of training examples: {len(train_data)}')
print(f'Number of validation examples: {len(valid_data)}')
print(f'Number of testing examples: {len(test_data)}')
# Out:
# Number of training examples: 17500
# Number of validation examples: 7500
# Number of testing examples: 25000

# %%
MAX_VOCAB_SIZE = 25_000

TEXT.build_vocab(train_data, max_size = MAX_VOCAB_SIZE)
LABEL.build_vocab(train_data)

# %%
print(f"Unique tokens in TEXT vocabulary: {len(TEXT.vocab)}")
print(f"Unique tokens in LABEL vocabulary: {len(LABEL.vocab)}")
# Out:
# Unique tokens in TEXT vocabulary: 25002
# Unique tokens in LABEL vocabulary: 2

# %%
print(TEXT.vocab.freqs.most_common(20))
# Out:
# [('the', 201216), (',', 191672), ('.', 164256), ('a', 108789), ('and', 108724), ('of', 99798), ('to', 92939), ('is', 75799), ('in', 61052), ('I', 54050), ('it', 53258), ('that', 48729), ('"', 44100), ("'s", 42873), ('this', 42355), ('-', 36652), ('/><br', 35379), ('was', 35008), ('as', 30305), ('with', 29788)]

# %%
print(TEXT.vocab.itos[:10])
# Out:
# ['<unk>', '<pad>', 'the', ',', '.', 'a', 'and', 'of', 'to', 'is']

# %%
print(LABEL.vocab.stoi)
# Out:
# defaultdict(None, {'neg': 0, 'pos': 1})

# %%
BATCH_SIZE = 128

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

train_iterator, valid_iterator, test_iterator = data.BucketIterator.splits(
    (train_data, valid_data, test_data), 
    batch_size = BATCH_SIZE,
    sort_within_batch=True,
    device = device)

# %%
import torch.nn as nn

class LSTM(nn.Module):
    def __init__(self, input_dim, embedding_dim, hidden_dim, output_dim):
        
        super().__init__()
        
        self.embedding = nn.Embedding(input_dim, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim)
        self.fc = nn.Linear(hidden_dim, output_dim)
        
    def forward(self, text, text_length):

        #[sentence len, batch size] => [sentence len, batch size, embedding size]
        embedded = self.embedding(text)
        
        packed = torch.nn.utils.rnn.pack_padded_sequence(embedded, text_length.to('cpu'))
        
        #[sentence len, batch size, embedding size] => 
        #  output: [sentence len, batch size, hidden size]
        #  hidden: [1, batch size, hidden size]
        packed_output, (hidden, cell) = self.lstm(packed)
        
        return self.fc(hidden.squeeze(0)).view(-1)

# %%
INPUT_DIM = len(TEXT.vocab)
EMBEDDING_DIM = 128
HIDDEN_DIM = 256
OUTPUT_DIM = 1

model = LSTM(INPUT_DIM, EMBEDDING_DIM, HIDDEN_DIM, OUTPUT_DIM)
model
# Out:
# LSTM(
#   (embedding): Embedding(25002, 128)
#   (lstm): LSTM(128, 256)
#   (fc): Linear(in_features=256, out_features=1, bias=True)
# )

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'The model has {count_parameters(model):,} trainable parameters')
# Out:
# The model has 3,595,777 trainable parameters

# %%
import torch.optim as optim

optimizer = optim.Adam(model.parameters(), lr=1e-4)

# %%
criterion = nn.BCEWithLogitsLoss()

# %%
model = model.to(device)
criterion = criterion.to(device)

# %%
def calculate_metrics(preds, y):
    
    #round predictions to the closest integer
    rounded_preds = torch.round(torch.sigmoid(preds))
    correct = (rounded_preds == y).float() #convert into float for division 
    Acc = correct.sum() / len(correct)
    TP = ((rounded_preds == 1) & (y == 1)).sum()
    TN = ((rounded_preds == 0) & (y == 0)).sum()
    FP = ((rounded_preds == 1) & (y == 0)).sum()
    FN = ((rounded_preds == 0) & (y == 1)).sum()
    return Acc,TP,TN,FP,FN

# %%
def train(model, iterator, optimizer, criterion):    
  epoch_loss = 0
  epoch_acc = 0
  TP = 0  
  TN = 0
  FP = 0
  FN = 0
  model.train()
  
  for batch in iterator:
    text, text_length = batch.text
    pred = model(text, text_length)
        
    loss = criterion(pred, batch.label)
        
    acc,tp,tn,fp,fn = calculate_metrics(pred, batch.label)
        
    optimizer.zero_grad()

    loss.backward()
        
    optimizer.step()
        
    epoch_loss += loss.item()
    epoch_acc += acc.item()
    TP += tp.item()
    TN += tn.item()
    FP += fp.item()
    FN += fn.item()
    
  #Acc = (TP+TN)/(TP+FP+TN+FN)  
  precision = TP/(TP+FP)
  recall = TP/(TP+FN)
  f1 = 2 * (precision*recall)/(precision+recall)    
    
  return epoch_loss/len(iterator), epoch_acc/len(iterator),precision,recall,f1,[TP,TN,FP,FN]

# %%
def evaluate(model, iterator, criterion):    
  epoch_loss = 0
  epoch_acc = 0
  TP = 0  
  TN = 0
  FP = 0
  FN = 0
  
  model.eval()
    
  with torch.no_grad():
    for batch in iterator:
      text, text_length = batch.text
      predictions = model(text, text_length)
            
      loss = criterion(predictions, batch.label)
            
      acc,tp,tn,fp,fn = calculate_metrics(predictions, batch.label)

      epoch_loss += loss.item()
      epoch_acc += acc.item()
      TP += tp.item()
      TN += tn.item()
      FP += fp.item()
      FN += fn.item()

  Acc = (TP+TN)/(TP+FP+TN+FN)  
  precision = TP/(TP+FP)
  recall = TP/(TP+FN)
  f1 = 2 * (precision*recall)/(precision+recall)      
        
  return epoch_loss / len(iterator), epoch_acc / len(iterator),precision,recall,f1,[TP,TN,FP,FN]

# %%
import time

def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
from prettytable import PrettyTable

N_EPOCHS = 25

best_valid_loss = float('inf')

for epoch in range(N_EPOCHS):

    start_time = time.time()
    
    train_loss, train_acc, train_prec, train_recall, train_f1, train_list = train(model, train_iterator, optimizer, criterion)
    valid_loss, valid_acc, valid_prec, valid_recall, valid_f1, valid_list = evaluate(model, valid_iterator, criterion)
    
    end_time = time.time()

    epoch_mins, epoch_secs = epoch_time(start_time, end_time)
    
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model.state_dict(), 'model.pt')
    
    print(f'\n\nEpoch: {epoch+1:02} | Epoch Time: {epoch_mins}m {epoch_secs}s\n')

    con = PrettyTable(['Train', 'Actual Positive', 'Actual Negative'])
    con.add_row(['Predicted Positive',train_list[0],train_list[2]])
    con.add_row(['Predicted Negative',train_list[3],train_list[1]])
    print(con)

    con = PrettyTable(['Valid', 'Actual Positive', 'Actual Negative'])
    con.add_row(['Predicted Positive',valid_list[0],valid_list[2]])
    con.add_row(['Predicted Negative',valid_list[3],valid_list[1]])
    print(con)

    table = PrettyTable(['Metrics', 'Train', 'Valid'])
    table.add_row(['Loss', f'{train_loss:.3f}',f'{valid_loss:.3f}'])
    table.add_row(['Accuracy', f'{train_acc*100:.2f}%',f'{valid_acc*100:.2f}%'])    
    table.add_row(['Precision', f'{train_prec*1:.2f}',f'{valid_prec*1:.2f}'])
    table.add_row(['Recall', f'{train_recall*1:.2f}',f'{valid_recall*1:.2f}'])
    table.add_row(['F1 score', f'{train_f1*1:.2f}',f'{valid_f1*1:.2f}'])
    print(table)
# Out:
# Epoch: 01 | Epoch Time: 0m 7s
#
# +--------------------+-----------------+-----------------+
# |       Train        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       3326      |       2660      |
# | Predicted Negative |       5364      |       6150      |
# +--------------------+-----------------+-----------------+
# +--------------------+-----------------+-----------------+
# |       Valid        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       2744      |       2139      |
# | Predicted Negative |       1066      |       1551      |
# +--------------------+-----------------+-----------------+
# +-----------+--------+--------+
# |  Metrics  | Train  | Valid  |
# +-----------+--------+--------+
# |    Loss   | 0.688  | 0.684  |
# |  Accuracy | 54.16% | 57.26% |
# | Precision |  0.56  |  0.56  |
# |   Recall  |  0.38  |  0.72  |
# |  F1 score |  0.45  |  0.63  |
# +-----------+--------+--------+
#
#
# Epoch: 02 | Epoch Time: 0m 7s
#
# +--------------------+-----------------+-----------------+
# |       Train        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       5531      |       3741      |
# | Predicted Negative |       3159      |       5069      |
# +--------------------+-----------------+-----------------+
# +--------------------+-----------------+-----------------+
# |       Valid        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       2580      |       1371      |
# | Predicted Negative |       1230      |       2319      |
# +--------------------+-----------------+-----------------+
# +-----------+--------+--------+
# |  Metrics  | Train  | Valid  |
# +-----------+--------+--------+
# |    Loss   | 0.680  | 0.632  |
# |  Accuracy | 60.57% | 65.32% |
# | Precision |  0.60  |  0.65  |
# |   Recall  |  0.64  |  0.68  |
# |  F1 score |  0.62  |  0.66  |
# +-----------+--------+--------+
#
#
# Epoch: 03 | Epoch Time: 0m 7s
#
# +--------------------+-----------------+-----------------+
# |       Train        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       6133      |       3173      |
# | Predicted Negative |       2557      |       5637      |
# +--------------------+-----------------+-----------------+
# +--------------------+-----------------+-----------------+
# |       Valid        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       2811      |       1387      |
# | Predicted Negative |       999       |       2303      |
# +--------------------+-----------------+-----------------+
# +-----------+--------+--------+
# |  Metrics  | Train  | Valid  |
# +-----------+--------+--------+
# |    Loss   | 0.611  | 0.602  |
# |  Accuracy | 67.24% | 68.20% |
# | Precision |  0.66  |  0.67  |
# |   Recall  |  0.71  |  0.74  |
# |  F1 score |  0.68  |  0.70  |
# +-----------+--------+--------+
#
#
# Epoch: 04 | Epoch Time: 0m 7s
#
# +--------------------+-----------------+-----------------+
# |       Train        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       6261      |       2748      |
# | Predicted Negative |       2429      |       6062      |
# +--------------------+-----------------+-----------------+
# +--------------------+-----------------+-----------------+
# |       Valid        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       2762      |       1116      |
# | Predicted Negative |       1048      |       2574      |
# +--------------------+-----------------+-----------------+
# +-----------+--------+--------+
# |  Metrics  | Train  | Valid  |
# +-----------+--------+--------+
# |    Loss   | 0.575  | 0.568  |
# |  Accuracy | 70.44% | 71.19% |
# | Precision |  0.69  |  0.71  |
# |   Recall  |  0.72  |  0.72  |
# |  F1 score |  0.71  |  0.72  |
# +-----------+--------+--------+
#
#
# Epoch: 05 | Epoch Time: 0m 7s
#
# +--------------------+-----------------+-----------------+
# |       Train        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       6580      |       2469      |
# | Predicted Negative |       2110      |       6341      |
# +--------------------+-----------------+-----------------+
# +--------------------+-----------------+-----------------+
# |       Valid        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       2664      |       870       |
# | Predicted Negative |       1146      |       2820      |
# +--------------------+-----------------+-----------------+
# +-----------+--------+--------+
# |  Metrics  | Train  | Valid  |
# +-----------+--------+--------+
# |    Loss   | 0.538  | 0.544  |
# |  Accuracy | 73.83% | 73.09% |
# | Precision |  0.73  |  0.75  |
# |   Recall  |  0.76  |  0.70  |
# |  F1 score |  0.74  |  0.73  |
# +-----------+--------+--------+
#
#
# Epoch: 06 | Epoch Time: 0m 7s
#
# +--------------------+-----------------+-----------------+
# |       Train        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       6690      |       2136      |
# | Predicted Negative |       2000      |       6674      |
# +--------------------+-----------------+-----------------+
# +--------------------+-----------------+-----------------+
# |       Valid        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       2987      |       1036      |
# | Predicted Negative |       823       |       2654      |
# +--------------------+-----------------+-----------------+
# +-----------+--------+--------+
# |  Metrics  | Train  | Valid  |
# +-----------+--------+--------+
# |    Loss   | 0.503  | 0.517  |
# |  Accuracy | 76.36% | 75.18% |
# | Precision |  0.76  |  0.74  |
# |   Recall  |  0.77  |  0.78  |
# |  F1 score |  0.76  |  0.76  |
# +-----------+--------+--------+
#
#
# Epoch: 07 | Epoch Time: 0m 8s
#
# +--------------------+-----------------+-----------------+
# |       Train        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       6797      |       1862      |
# | Predicted Negative |       1893      |       6948      |
# +--------------------+-----------------+-----------------+
# +--------------------+-----------------+-----------------+
# |       Valid        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       2674      |       593       |
# | Predicted Negative |       1136      |       3097      |
# +--------------------+-----------------+-----------------+
# +-----------+--------+--------+
# |  Metrics  | Train  | Valid  |
# +-----------+--------+--------+
# |    Loss   | 0.469  | 0.497  |
# |  Accuracy | 78.53% | 76.92% |
# | Precision |  0.78  |  0.82  |
# |   Recall  |  0.78  |  0.70  |
# |  F1 score |  0.78  |  0.76  |
# +-----------+--------+--------+
#
#
# Epoch: 08 | Epoch Time: 0m 8s
#
# +--------------------+-----------------+-----------------+
# |       Train        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       6995      |       1781      |
# | Predicted Negative |       1695      |       7029      |
# +--------------------+-----------------+-----------------+
# +--------------------+-----------------+-----------------+
# |       Valid        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       2938      |       837       |
# | Predicted Negative |       872       |       2853      |
# +--------------------+-----------------+-----------------+
# +-----------+--------+--------+
# |  Metrics  | Train  | Valid  |
# +-----------+--------+--------+
# |    Loss   | 0.447  | 0.488  |
# |  Accuracy | 80.15% | 77.22% |
# | Precision |  0.80  |  0.78  |
# |   Recall  |  0.80  |  0.77  |
# |  F1 score |  0.80  |  0.77  |
# +-----------+--------+--------+
#
#
# Epoch: 09 | Epoch Time: 0m 8s
#
# +--------------------+-----------------+-----------------+
# |       Train        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       7136      |       1763      |
# | Predicted Negative |       1554      |       7047      |
# +--------------------+-----------------+-----------------+
# +--------------------+-----------------+-----------------+
# |       Valid        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       2699      |       520       |
# | Predicted Negative |       1111      |       3170      |
# +--------------------+-----------------+-----------------+
# +-----------+--------+--------+
# |  Metrics  | Train  | Valid  |
# +-----------+--------+--------+
# |    Loss   | 0.432  | 0.478  |
# |  Accuracy | 81.05% | 78.25% |
# | Precision |  0.80  |  0.84  |
# |   Recall  |  0.82  |  0.71  |
# |  F1 score |  0.81  |  0.77  |
# +-----------+--------+--------+
#
#
# Epoch: 10 | Epoch Time: 0m 8s
#
# +--------------------+-----------------+-----------------+
# |       Train        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       7153      |       1646      |
# | Predicted Negative |       1537      |       7164      |
# +--------------------+-----------------+-----------------+
# +--------------------+-----------------+-----------------+
# |       Valid        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       3004      |       715       |
# | Predicted Negative |       806       |       2975      |
# +--------------------+-----------------+-----------------+
# +-----------+--------+--------+
# |  Metrics  | Train  | Valid  |
# +-----------+--------+--------+
# |    Loss   | 0.418  | 0.447  |
# |  Accuracy | 81.82% | 79.71% |
# | Precision |  0.81  |  0.81  |
# |   Recall  |  0.82  |  0.79  |
# |  F1 score |  0.82  |  0.80  |
# +-----------+--------+--------+
#
#
# Epoch: 11 | Epoch Time: 0m 8s
#
# +--------------------+-----------------+-----------------+
# |       Train        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       7357      |       1419      |
# | Predicted Negative |       1333      |       7391      |
# +--------------------+-----------------+-----------------+
# +--------------------+-----------------+-----------------+
# |       Valid        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       3288      |       1050      |
# | Predicted Negative |       522       |       2640      |
# +--------------------+-----------------+-----------------+
# +-----------+--------+--------+
# |  Metrics  | Train  | Valid  |
# +-----------+--------+--------+
# |    Loss   | 0.373  | 0.451  |
# |  Accuracy | 84.27% | 79.00% |
# | Precision |  0.84  |  0.76  |
# |   Recall  |  0.85  |  0.86  |
# |  F1 score |  0.84  |  0.81  |
# +-----------+--------+--------+
#
#
# Epoch: 12 | Epoch Time: 0m 8s
#
# +--------------------+-----------------+-----------------+
# |       Train        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       7410      |       1510      |
# | Predicted Negative |       1280      |       7300      |
# +--------------------+-----------------+-----------------+
# +--------------------+-----------------+-----------------+
# |       Valid        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       2844      |       517       |
# | Predicted Negative |       966       |       3173      |
# +--------------------+-----------------+-----------------+
# +-----------+--------+--------+
# |  Metrics  | Train  | Valid  |
# +-----------+--------+--------+
# |    Loss   | 0.380  | 0.440  |
# |  Accuracy | 84.07% | 80.20% |
# | Precision |  0.83  |  0.85  |
# |   Recall  |  0.85  |  0.75  |
# |  F1 score |  0.84  |  0.79  |
# +-----------+--------+--------+
#
#
# Epoch: 13 | Epoch Time: 0m 8s
#
# +--------------------+-----------------+-----------------+
# |       Train        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       7525      |       1273      |
# | Predicted Negative |       1165      |       7537      |
# +--------------------+-----------------+-----------------+
# +--------------------+-----------------+-----------------+
# |       Valid        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       2753      |       486       |
# | Predicted Negative |       1057      |       3204      |
# +--------------------+-----------------+-----------------+
# +-----------+--------+--------+
# |  Metrics  | Train  | Valid  |
# +-----------+--------+--------+
# |    Loss   | 0.340  | 0.450  |
# |  Accuracy | 86.07% | 79.41% |
# | Precision |  0.86  |  0.85  |
# |   Recall  |  0.87  |  0.72  |
# |  F1 score |  0.86  |  0.78  |
# +-----------+--------+--------+
#
#
# Epoch: 14 | Epoch Time: 0m 8s
#
# +--------------------+-----------------+-----------------+
# |       Train        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       7591      |       1193      |
# | Predicted Negative |       1099      |       7617      |
# +--------------------+-----------------+-----------------+
# +--------------------+-----------------+-----------------+
# |       Valid        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       3134      |       627       |
# | Predicted Negative |       676       |       3063      |
# +--------------------+-----------------+-----------------+
# +-----------+--------+--------+
# |  Metrics  | Train  | Valid  |
# +-----------+--------+--------+
# |    Loss   | 0.325  | 0.414  |
# |  Accuracy | 86.90% | 82.63% |
# | Precision |  0.86  |  0.83  |
# |   Recall  |  0.87  |  0.82  |
# |  F1 score |  0.87  |  0.83  |
# +-----------+--------+--------+
#
#
# Epoch: 15 | Epoch Time: 0m 8s
#
# +--------------------+-----------------+-----------------+
# |       Train        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       7658      |       1065      |
# | Predicted Negative |       1032      |       7745      |
# +--------------------+-----------------+-----------------+
# +--------------------+-----------------+-----------------+
# |       Valid        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       2998      |       501       |
# | Predicted Negative |       812       |       3189      |
# +--------------------+-----------------+-----------------+
# +-----------+--------+--------+
# |  Metrics  | Train  | Valid  |
# +-----------+--------+--------+
# |    Loss   | 0.301  | 0.400  |
# |  Accuracy | 88.02% | 82.45% |
# | Precision |  0.88  |  0.86  |
# |   Recall  |  0.88  |  0.79  |
# |  F1 score |  0.88  |  0.82  |
# +-----------+--------+--------+
#
#
# Epoch: 16 | Epoch Time: 0m 8s
#
# +--------------------+-----------------+-----------------+
# |       Train        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       7736      |       1057      |
# | Predicted Negative |       954       |       7753      |
# +--------------------+-----------------+-----------------+
# +--------------------+-----------------+-----------------+
# |       Valid        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       3094      |       571       |
# | Predicted Negative |       716       |       3119      |
# +--------------------+-----------------+-----------------+
# +-----------+--------+--------+
# |  Metrics  | Train  | Valid  |
# +-----------+--------+--------+
# |    Loss   | 0.296  | 0.391  |
# |  Accuracy | 88.51% | 82.82% |
# | Precision |  0.88  |  0.84  |
# |   Recall  |  0.89  |  0.81  |
# |  F1 score |  0.88  |  0.83  |
# +-----------+--------+--------+
#
#
# Epoch: 17 | Epoch Time: 0m 8s
#
# +--------------------+-----------------+-----------------+
# |       Train        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       7669      |       1014      |
# | Predicted Negative |       1021      |       7796      |
# +--------------------+-----------------+-----------------+
# +--------------------+-----------------+-----------------+
# |       Valid        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       3070      |       503       |
# | Predicted Negative |       740       |       3187      |
# +--------------------+-----------------+-----------------+
# +-----------+--------+--------+
# |  Metrics  | Train  | Valid  |
# +-----------+--------+--------+
# |    Loss   | 0.294  | 0.405  |
# |  Accuracy | 88.37% | 83.41% |
# | Precision |  0.88  |  0.86  |
# |   Recall  |  0.88  |  0.81  |
# |  F1 score |  0.88  |  0.83  |
# +-----------+--------+--------+
#
#
# Epoch: 18 | Epoch Time: 0m 8s
#
# +--------------------+-----------------+-----------------+
# |       Train        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       7837      |       936       |
# | Predicted Negative |       853       |       7874      |
# +--------------------+-----------------+-----------------+
# +--------------------+-----------------+-----------------+
# |       Valid        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       3237      |       682       |
# | Predicted Negative |       573       |       3008      |
# +--------------------+-----------------+-----------------+
# +-----------+--------+--------+
# |  Metrics  | Train  | Valid  |
# +-----------+--------+--------+
# |    Loss   | 0.266  | 0.384  |
# |  Accuracy | 89.78% | 83.23% |
# | Precision |  0.89  |  0.83  |
# |   Recall  |  0.90  |  0.85  |
# |  F1 score |  0.90  |  0.84  |
# +-----------+--------+--------+
#
#
# Epoch: 19 | Epoch Time: 0m 8s
#
# +--------------------+-----------------+-----------------+
# |       Train        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       7812      |       966       |
# | Predicted Negative |       878       |       7844      |
# +--------------------+-----------------+-----------------+
# +--------------------+-----------------+-----------------+
# |       Valid        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       3016      |       425       |
# | Predicted Negative |       794       |       3265      |
# +--------------------+-----------------+-----------------+
# +-----------+--------+--------+
# |  Metrics  | Train  | Valid  |
# +-----------+--------+--------+
# |    Loss   | 0.265  | 0.403  |
# |  Accuracy | 89.46% | 83.71% |
# | Precision |  0.89  |  0.88  |
# |   Recall  |  0.90  |  0.79  |
# |  F1 score |  0.89  |  0.83  |
# +-----------+--------+--------+
#
#
# Epoch: 20 | Epoch Time: 0m 8s
#
# +--------------------+-----------------+-----------------+
# |       Train        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       7861      |       873       |
# | Predicted Negative |       829       |       7937      |
# +--------------------+-----------------+-----------------+
# +--------------------+-----------------+-----------------+
# |       Valid        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       3070      |       531       |
# | Predicted Negative |       740       |       3159      |
# +--------------------+-----------------+-----------------+
# +-----------+--------+--------+
# |  Metrics  | Train  | Valid  |
# +-----------+--------+--------+
# |    Loss   | 0.252  | 0.398  |
# |  Accuracy | 90.26% | 83.04% |
# | Precision |  0.90  |  0.85  |
# |   Recall  |  0.90  |  0.81  |
# |  F1 score |  0.90  |  0.83  |
# +-----------+--------+--------+
#
#
# Epoch: 21 | Epoch Time: 0m 8s
#
# +--------------------+-----------------+-----------------+
# |       Train        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       7755      |       861       |
# | Predicted Negative |       935       |       7949      |
# +--------------------+-----------------+-----------------+
# +--------------------+-----------------+-----------------+
# |       Valid        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       3396      |       793       |
# | Predicted Negative |       414       |       2897      |
# +--------------------+-----------------+-----------------+
# +-----------+--------+--------+
# |  Metrics  | Train  | Valid  |
# +-----------+--------+--------+
# |    Loss   | 0.265  | 0.390  |
# |  Accuracy | 89.73% | 83.87% |
# | Precision |  0.90  |  0.81  |
# |   Recall  |  0.89  |  0.89  |
# |  F1 score |  0.90  |  0.85  |
# +-----------+--------+--------+
#
#
# Epoch: 22 | Epoch Time: 0m 8s
#
# +--------------------+-----------------+-----------------+
# |       Train        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       7907      |       825       |
# | Predicted Negative |       783       |       7985      |
# +--------------------+-----------------+-----------------+
# +--------------------+-----------------+-----------------+
# |       Valid        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       2900      |       366       |
# | Predicted Negative |       910       |       3324      |
# +--------------------+-----------------+-----------------+
# +-----------+--------+--------+
# |  Metrics  | Train  | Valid  |
# +-----------+--------+--------+
# |    Loss   | 0.238  | 0.408  |
# |  Accuracy | 90.81% | 82.93% |
# | Precision |  0.91  |  0.89  |
# |   Recall  |  0.91  |  0.76  |
# |  F1 score |  0.91  |  0.82  |
# +-----------+--------+--------+
#
#
# Epoch: 23 | Epoch Time: 0m 8s
#
# +--------------------+-----------------+-----------------+
# |       Train        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       8036      |       729       |
# | Predicted Negative |       654       |       8081      |
# +--------------------+-----------------+-----------------+
# +--------------------+-----------------+-----------------+
# |       Valid        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       3111      |       460       |
# | Predicted Negative |       699       |       3230      |
# +--------------------+-----------------+-----------------+
# +-----------+--------+--------+
# |  Metrics  | Train  | Valid  |
# +-----------+--------+--------+
# |    Loss   | 0.212  | 0.397  |
# |  Accuracy | 92.09% | 84.52% |
# | Precision |  0.92  |  0.87  |
# |   Recall  |  0.92  |  0.82  |
# |  F1 score |  0.92  |  0.84  |
# +-----------+--------+--------+
#
#
# Epoch: 24 | Epoch Time: 0m 8s
#
# +--------------------+-----------------+-----------------+
# |       Train        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       8078      |       637       |
# | Predicted Negative |       612       |       8173      |
# +--------------------+-----------------+-----------------+
# +--------------------+-----------------+-----------------+
# |       Valid        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       3316      |       645       |
# | Predicted Negative |       494       |       3045      |
# +--------------------+-----------------+-----------------+
# +-----------+--------+--------+
# |  Metrics  | Train  | Valid  |
# +-----------+--------+--------+
# |    Loss   | 0.195  | 0.380  |
# |  Accuracy | 92.85% | 84.79% |
# | Precision |  0.93  |  0.84  |
# |   Recall  |  0.93  |  0.87  |
# |  F1 score |  0.93  |  0.85  |
# +-----------+--------+--------+
#
#
# Epoch: 25 | Epoch Time: 0m 8s
#
# +--------------------+-----------------+-----------------+
# |       Train        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       8045      |       728       |
# | Predicted Negative |       645       |       8082      |
# +--------------------+-----------------+-----------------+
# +--------------------+-----------------+-----------------+
# |       Valid        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       3357      |       723       |
# | Predicted Negative |       453       |       2967      |
# +--------------------+-----------------+-----------------+
# +-----------+--------+--------+
# |  Metrics  | Train  | Valid  |
# +-----------+--------+--------+
# |    Loss   | 0.208  | 0.381  |
# |  Accuracy | 92.16% | 84.26% |
# | Precision |  0.92  |  0.82  |
# |   Recall  |  0.93  |  0.88  |
# |  F1 score |  0.92  |  0.85  |
# +-----------+--------+--------+

# %%
model.load_state_dict(torch.load('model.pt'))

test_loss, test_acc, test_prec, test_recall, test_f1, test_list = evaluate(model, test_iterator, criterion)

con = PrettyTable(['Test', 'Actual Positive', 'Actual Negative'])
con.add_row(['Predicted Positive',valid_list[0],valid_list[2]])
con.add_row(['Predicted Negative',valid_list[3],valid_list[1]])
print(con)

table = PrettyTable(['Metrics', 'Test'])
table.add_row(['Loss', f'{test_loss:.3f}'])
table.add_row(['Accuracy', f'{test_acc*100:.2f}%'])    
table.add_row(['Precision', f'{test_prec*1:.2f}'])
table.add_row(['Recall', f'{test_recall*1:.2f}'])
table.add_row(['F1 score', f'{test_f1*1:.2f}'])
print(table)
# Out:
# +--------------------+-----------------+-----------------+
# |        Test        | Actual Positive | Actual Negative |
# +--------------------+-----------------+-----------------+
# | Predicted Positive |       3357      |       723       |
# | Predicted Negative |       453       |       2967      |
# +--------------------+-----------------+-----------------+
# +-----------+--------+
# |  Metrics  |  Test  |
# +-----------+--------+
# |    Loss   | 0.374  |
# |  Accuracy | 84.91% |
# | Precision |  0.84  |
# |   Recall  |  0.87  |
# |  F1 score |  0.85  |
# +-----------+--------+
